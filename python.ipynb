# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('student_data.csv')

# %%
data.head(6)
# Out:
#    StudentID  Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA      Major  \
# 0          1    Male   24                 37           90.75  3.47       Arts
# 1          2  Female   22                 37           74.90  2.32  Education
# 2          3    Male   22                 10           53.36  2.38   Business
# 3          4    Male   24                 10           70.26  3.46    Science
# 4          5    Male   18                 19           74.87  2.31  Education
# 5          6  Female   20                 17           86.01  2.47   Business
#
#   PartTimeJob ExtraCurr-Activities
# 0         Yes                   No
# 1          No                   No
# 2          No                   No
# 3         Yes                   No
# 4         Yes                   No
# 5         Yes                   No

# %%
data.describe()
# Out:
#         StudentID         Age  StudyHoursPerWeek  AttendanceRate        GPA
# count  500.000000  500.000000         500.000000      500.000000  500.00000
# mean   250.500000   20.956000          19.876000       74.990380    2.98516
# std    144.481833    2.000517          11.471347       14.565917    0.56362
# min      1.000000   18.000000           1.000000       50.010000    2.00000
# 25%    125.750000   19.000000          10.000000       62.607500    2.48750
# 50%    250.500000   21.000000          20.500000       75.730000    3.00000
# 75%    375.250000   23.000000          30.000000       87.220000    3.48000
# max    500.000000   24.000000          39.000000       99.970000    3.99000

# %%
data.tail(5)
# Out:
#      StudentID  Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA  \
# 495        496    Male   22                 37           76.61  2.97
# 496        497    Male   23                 11           56.29  3.20
# 497        498  Female   20                  6           56.64  3.20
# 498        499    Male   22                 18           57.18  2.05
# 499        500  Female   24                 21           96.99  2.64
#
#            Major PartTimeJob ExtraCurr-Activities
# 495      Science          No                   No
# 496      Science          No                   No
# 497      Science          No                  Yes
# 498     Business          No                  Yes
# 499  Engineering          No                   No

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.shape
# Out:
# (500, 9)

# %%
data_encoded = pd.get_dummies(data, columns=['Gender', 'Major'], drop_first=True)

# %%
data_encoded.head()
# Out:
#    StudentID  Age  StudyHoursPerWeek  AttendanceRate   GPA PartTimeJob  \
# 0          1   24                 37           90.75  3.47         Yes
# 1          2   22                 37           74.90  2.32          No
# 2          3   22                 10           53.36  2.38          No
# 3          4   24                 10           70.26  3.46         Yes
# 4          5   18                 19           74.87  2.31         Yes
#
#   ExtraCurr-Activities  Gender_Male  Major_Business  Major_Education  \
# 0                   No         True           False            False
# 1                   No        False           False             True
# 2                   No         True            True            False
# 3                   No         True           False            False
# 4                   No         True           False             True
#
#    Major_Engineering  Major_Science
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False           True
# 4              False          False

# %%
from sklearn.model_selection import train_test_split

# %%
plt.plot(X_test,y_test,'g.',label='test_data')
plt.xlabel('X_test')
plt.xlabel('y_test')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()
